# %% [markdown]
# # 💸 **RepayAI – Neural Network based Loan Risk Model**
# ---
#
# ## 🔍 Overview
#
# We will be working with a subset of the **LendingClub Dataset**:
# 🔗 [Click here](https://1drv.ms/f/c/a27ce39f4c705a7c/Es4NK0HEoLtJn1RoZsPwoF4BKpI3uwMEHaFvKg-qb9TqmA)
#
# > 🏦 **LendingClub** is a US-based peer-to-peer lending company headquartered in San Francisco.
# It was the first P2P lender to register its offerings with the **SEC** and to offer **loan trading** on a secondary market. Today, LendingClub stands as the **world’s largest peer-to-peer lending platform**.
#
# ---
#
# ## 🎯 Project Goal
#
# Can we **predict whether a borrower will repay their loan or not** based on historical loan data?
#
# Given the **`loan_status`** column as our label:
# - ✅ Fully Paid → Positive class
# - ❌ Charged Off → Negative class
#
# We'll aim to build a **binary classification model** using **Keras** that can help LendingClub:
# - Evaluate new loan applications
# - Reduce default risk
# - Improve lending decision-making
#
# ---
#
# ## 📁 Dataset Description
#
# The dataset includes:
# - 💳 **Financial information** (loan amount, interest rate, installment, etc.)
# - 👤 **Personal details** (employment title, annual income, home ownership, etc.)
# - 🕵️‍♂️ **Credit history & inquiries**
# - 📆 **Loan timeline** (issue date, term, earliest credit line, etc.)
# - 🏷️ **Target variable:** `loan_status` (Fully Paid / Charged Off)
#
# ---
#
# ## 📌 Key Objective
#
# - 🔍 Perform **exploratory data analysis (EDA)**
# - 🧼 Preprocess data (handle missing values, encoding, feature scaling)
# - 🧠 Build a **Keras neural network model**
# - 📉 Evaluate performance using classification metrics:
#   - Accuracy
#   - Precision
#   - Recall
#   - F1 Score
#
# ---
# ---
#
#
# # ❇️ Data Overview:

# %% [markdown]
# There are many LendingClub data sets on Kaggle. Here is the information on this particular data set:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LoanStatNew</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>loan_amnt</td>
#       <td>The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>term</td>
#       <td>The number of payments on the loan. Values are in months and can be either 36 or 60.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>int_rate</td>
#       <td>Interest Rate on the loan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>installment</td>
#       <td>The monthly payment owed by the borrower if the loan originates.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>grade</td>
#       <td>LC assigned loan grade</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>sub_grade</td>
#       <td>LC assigned loan subgrade</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>emp_title</td>
#       <td>The job title supplied by the Borrower when applying for the loan.*</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>emp_length</td>
#       <td>Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>home_ownership</td>
#       <td>The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>annual_inc</td>
#       <td>The self-reported annual income provided by the borrower during registration.</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>verification_status</td>
#       <td>Indicates if income was verified by LC, not verified, or if the income source was verified</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>issue_d</td>
#       <td>The month which the loan was funded</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>loan_status</td>
#       <td>Current status of the loan</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>purpose</td>
#       <td>A category provided by the borrower for the loan request.</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>title</td>
#       <td>The loan title provided by the borrower</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>zip_code</td>
#       <td>The first 3 numbers of the zip code provided by the borrower in the loan application.</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>addr_state</td>
#       <td>The state provided by the borrower in the loan application</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>dti</td>
#       <td>A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>earliest_cr_line</td>
#       <td>The month the borrower's earliest reported credit line was opened</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>open_acc</td>
#       <td>The number of open credit lines in the borrower's credit file.</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>pub_rec</td>
#       <td>Number of derogatory public records</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>revol_bal</td>
#       <td>Total credit revolving balance</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>revol_util</td>
#       <td>Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>total_acc</td>
#       <td>The total number of credit lines currently in the borrower's credit file</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>initial_list_status</td>
#       <td>The initial listing status of the loan. Possible values are – W, F</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>application_type</td>
#       <td>Indicates whether the loan is an individual application or a joint application with two co-borrowers</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>mort_acc</td>
#       <td>Number of mortgage accounts.</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>pub_rec_bankruptcies</td>
#       <td>Number of public record bankruptcies</td>
#     </tr>
#   </tbody>
# </table>
#
# ---
# ----

# %% [markdown]
# # ❇️ Starter Code:

# %%
import pandas as pd

# %%
data_info = pd.read_csv('DATA/lending_club_info.csv',index_col='LoanStatNew')
data_info
# Out:
#                                                             Description
# LoanStatNew
# loan_amnt             The listed amount of the loan applied for by t...
# term                  The number of payments on the loan. Values are...
# int_rate                                      Interest Rate on the loan
# installment           The monthly payment owed by the borrower if th...
# grade                                            LC assigned loan grade
# sub_grade                                     LC assigned loan subgrade
# emp_title             The job title supplied by the Borrower when ap...
# emp_length            Employment length in years. Possible values ar...
# home_ownership        The home ownership status provided by the borr...
# annual_inc            The self-reported annual income provided by th...
# verification_status   Indicates if income was verified by LC, not ve...
# issue_d                             The month which the loan was funded
# ...

# %%
print(data_info.loc['revol_util']['Description'])
# Out:
# Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.

# %%
def feat_info(col_name):
    print(data_info.loc[col_name]['Description'])

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %% [markdown]
# ---
# ---
# # ❇️ Loading the data and other imports:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.dpi'] = 300

# %matplotlib inline

# %%
df = pd.read_csv('DATA/lending_club_loan_two.csv')

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %% [markdown]
# ------
# ------
#
# # 📊 Exploratory Data Analysis (EDA):

# %% [markdown]
# #### 1. Analyzing Loan Status:

# %%
plt.figure(figsize = (5,3))
sns.countplot(x = df['loan_status'], hue = df['loan_status'] ,palette = 'rocket')

plt.xlabel('Loan Status')  
plt.ylabel('Count') 
plt.title('Analyzing Loan Status')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Analyzing Loan Amount:

# %%
plt.figure(figsize = (12,5))
sns.distplot(df['loan_amnt'], kde = False, color = 'royalblue')

plt.xlabel('Loan Amount')  
plt.ylabel('Density') 
plt.title('Analyzing Loan Amount')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qf/32t2k01x4jvc8n9npp_m0plm0000gn/T/ipykernel_7595/1478406991.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['loan_amnt'], kde = False, color = 'royalblue')

# %% [markdown]
# #### 3. Analyzing Correlation:

# %%
df.corr(numeric_only = True)
# Out:
#                       loan_amnt  int_rate  installment  annual_inc       dti  \
# loan_amnt              1.000000  0.168921     0.953929    0.336887  0.016636
# int_rate               0.168921  1.000000     0.162758   -0.056771  0.079038
# installment            0.953929  0.162758     1.000000    0.330381  0.015786
# annual_inc             0.336887 -0.056771     0.330381    1.000000 -0.081685
# dti                    0.016636  0.079038     0.015786   -0.081685  1.000000
# open_acc               0.198556  0.011649     0.188973    0.136150  0.136181
# pub_rec               -0.077779  0.060986    -0.067892   -0.013720 -0.017639
# revol_bal              0.328320 -0.011280     0.316455    0.299773  0.063571
# revol_util             0.099911  0.293659     0.123915    0.027871  0.088375
# total_acc              0.223886 -0.036404     0.202430    0.193023  0.102128
# mort_acc               0.222315 -0.082583     0.193694    0.236320 -0.025439
# ...

# %% [markdown]
# **Visualizing Correlation using Heatmap:**

# %%
plt.figure(figsize = (16,8))
sns.heatmap(df.corr(numeric_only = True) , annot = True)

plt.suptitle('Correlation Matrix')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4. There is almost perfect correlation of "loan_amnt" with the "installment" feature. Exploring this feature further:

# %%
plt.figure(figsize = (12,5))
sns.scatterplot( x = 'installment' , y = 'loan_amnt' , data = df, color = 'royalblue')

plt.xlabel('Installment')  
plt.ylabel('Loan Amount') 
plt.title('Loan Amount vs Installment')

plt.tight_layout()
plt.show()

# %%
feat_info('installment')
# Out:
# The monthly payment owed by the borrower if the loan originates.

# %%
feat_info('loan_amnt')
# Out:
# The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.

# %% [markdown]
# #### 5. Analyzing the relationship between Loan status and Loan Amount:

# %%
plt.figure(figsize = (12,6))
sns.boxplot( x = df['loan_status'] , y = df['loan_amnt'], hue = df['loan_status'] , palette = 'mako')

plt.xlabel('Loan Status')  
plt.ylabel('Loan Amount') 
plt.title('Analyzing Loan Status vs Loan Amount')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6. Calculating the summary statistics for the loan amount, grouped by the loan_status:

# %%
grouper_lstat = df.groupby('loan_status')
view_lamnt = grouper_lstat['loan_amnt']

view_lamnt.describe()
# Out:
#                 count          mean          std     min     25%      50%  \
# loan_status
# Charged Off   77673.0  15126.300967  8505.090557  1000.0  8525.0  14000.0
# Fully Paid   318357.0  13866.878771  8302.319699   500.0  7500.0  12000.0
#
#                  75%      max
# loan_status
# Charged Off  20000.0  40000.0
# Fully Paid   19225.0  40000.0

# %% [markdown]
# #### 7. Exploring the Grade and SubGrade columns that LendingClub attributes to the loans. Checking out unique possible grades and subgrades:

# %%
diff_grade = df['grade'].unique()
np.sort(diff_grade)
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G'], dtype=object)

# %%
diff_subgrade = df['sub_grade'].unique()
np.sort(diff_subgrade)
# Out:
# array(['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1',
#        'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2',
#        'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3',
#        'G4', 'G5'], dtype=object)

# %% [markdown]
# #### 8. Visualizing assigned Loan Grade with Loan Status:

# %%
plt.figure(figsize = (12,5))
sns.countplot(x = df['grade'] , hue = df['loan_status'], palette = 'rocket')

plt.xlabel('Loan Grade')  
plt.ylabel('Count') 
plt.title('Visualizing the Assigned Loan Grade')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 9. Initially visualizing the Loan Subgrade, later on involving up the Loan Status for analysis:

# %%
plt.figure(figsize = (14,5))
sorted_subgrde = np.sort(df['sub_grade'])
sns.countplot(x = sorted_subgrde , hue = sorted_subgrde, palette = 'rocket')

plt.xlabel('Loan Subgrade')
plt.ylabel('Count')
plt.title('Analyzing the Subgrade')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (14,6))
sorted_subgrde = np.sort(df['sub_grade'])
sns.countplot(x = sorted_subgrde , hue = df['loan_status'], palette = 'rocket')

plt.xlabel('Loan Subgrade')
plt.ylabel('Count')
plt.title('Analyzing the Subgrade')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 10. Checking out the F & G subgrade:

# %%
plt.figure(figsize = (14,5))

FG_df = df[(df['grade'] == 'F') | (df['grade'] == 'G')]
sorted_subgrade = np.sort(FG_df['sub_grade'])


sns.countplot(x = sorted_subgrade, hue = FG_df['loan_status'] , palette = 'rocket')

plt.xlabel('Subgrade')
plt.ylabel('Count')
plt.title('Analyzing the F & G Subgrade')
plt.show()

# %% [markdown]
# #### 11. Creating a new column called 'loan_repaid' which will contain a 1 if the loan status was "Fully Paid" and a 0 if it was "Charged Off":

# %%
df['loan_repaid']= pd.get_dummies(df['loan_status'] , drop_first = True).astype(int)
#df.head()

df[['loan_status' , 'loan_repaid']]
# Out:
#         loan_status  loan_repaid
# 0        Fully Paid            1
# 1        Fully Paid            1
# 2        Fully Paid            1
# 3        Fully Paid            1
# 4       Charged Off            0
# ...             ...          ...
# 396025   Fully Paid            1
# 396026   Fully Paid            1
# 396027   Fully Paid            1
# 396028   Fully Paid            1
# 396029   Fully Paid            1
#
# [396030 rows x 2 columns]

# %% [markdown]
# #### 12. Correlation Analysis with Loan Repayment Status:

# %%
correl_df = df.corr(numeric_only = True)
loan_repaid_corr = correl_df['loan_repaid']

print('Correlation Values of Various Features with Loan Repayment Status :')
loan_repaid_corr
# Out:
# Correlation Values of Various Features with Loan Repayment Status :
# loan_amnt              -0.059836
# int_rate               -0.247758
# installment            -0.041082
# annual_inc              0.053432
# dti                    -0.062413
# open_acc               -0.028012
# pub_rec                -0.019933
# revol_bal               0.010892
# revol_util             -0.082373
# total_acc               0.017893
# mort_acc                0.073111
# pub_rec_bankruptcies   -0.009383
# loan_repaid             1.000000
# Name: loan_repaid, dtype: float64

# %%
plt.figure(figsize = (16,6))
sns.barplot(loan_repaid_corr.drop('loan_repaid'), palette = 'rocket')

plt.xlabel('Features')
plt.ylabel('Correlation Value with Loan Repayment status')
plt.title('Correlation Analysis with Loan Repayment Status')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qf/32t2k01x4jvc8n9npp_m0plm0000gn/T/ipykernel_7595/3594689377.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(loan_repaid_corr.drop('loan_repaid'), palette = 'rocket')

# %% [markdown]
# ----
# ----
# # 🚫 Data PreProcessing - Missing Data:

# %%
df.head(5)
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ... pub_rec  \
# 0                Marketing  10+ years           RENT    117000.0  ...     0.0
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...     0.0
# 2             Statistician   < 1 year           RENT     43057.0  ...     0.0
# 3          Client Advocate    6 years           RENT     54000.0  ...     0.0
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...     0.0
#
#   revol_bal revol_util total_acc initial_list_status  application_type  \
# ...

# %%
print('Number of Rows in DataFrame:' , len(df))
# Out:
# Number of Rows in DataFrame: 396030

# %% [markdown]
# #### 1. Analyzing the total count of missing values per column:

# %%
pd.DataFrame({'Feature': df.columns, 
              'Missing Data Count': (df.isnull().sum().values)
             })
# Out:
#                  Feature  Missing Data Count
# 0              loan_amnt                   0
# 1                   term                   0
# 2               int_rate                   0
# 3            installment                   0
# 4                  grade                   0
# 5              sub_grade                   0
# 6              emp_title               22927
# 7             emp_length               18301
# 8         home_ownership                   0
# 9             annual_inc                   0
# 10   verification_status                   0
# 11               issue_d                   0
# 12           loan_status                   0
# 13               purpose                   0
# 14                 title                1756
# 15                   dti                   0
# 16      earliest_cr_line                   0
# 17              open_acc                   0
# 18               pub_rec                   0
# 19             revol_bal                   0
# ...

# %% [markdown]
# **Converting in term of percentage of the total DataFrame:**

# %%
print('\n')
print('Total Data Count under each feature should be:' , len(df))
print('\n')

missing_df = pd.DataFrame({'Feature': df.columns, 
              'Missing Count': (df.isnull().sum().values),
              'Total Data Count': (df.count().values),
              'Data Missing Percent': ((df.isnull().sum().values / len(df))*100)
             })

missing_df
# Out:
# Total Data Count under each feature should be: 396030
#                  Feature  Missing Count  Total Data Count  \
# 0              loan_amnt              0            396030
# 1                   term              0            396030
# 2               int_rate              0            396030
# 3            installment              0            396030
# 4                  grade              0            396030
# 5              sub_grade              0            396030
# 6              emp_title          22927            373103
# 7             emp_length          18301            377729
# 8         home_ownership              0            396030
# 9             annual_inc              0            396030
# 10   verification_status              0            396030
# 11               issue_d              0            396030
# 12           loan_status              0            396030
# 13               purpose              0            396030
# ...

# %% [markdown]
# #### 2. Checking the "emp_title" & "emp_length", and dropping any of them if found not useful:

# %%
print('\n')
feat_info('emp_title')
print('\n')
feat_info('emp_length')
print('\n')
# Out:
# The job title supplied by the Borrower when applying for the loan.*
#
#
# Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.

# %% [markdown]
# **Analyzing employment job titles:**

# %%
len(df.emp_title.unique())
# Out:
# 173106

# %%
df.emp_title.value_counts()
# Out:
# emp_title
# Teacher                    4389
# Manager                    4250
# Registered Nurse           1856
# RN                         1846
# Supervisor                 1830
#                            ...
# Postman                       1
# McCarthy & Holthus, LLC       1
# jp flooring                   1
# Histology Technologist        1
# Gracon Services, Inc          1
# Name: count, Length: 173105, dtype: int64

# %% [markdown]
# **Realistically there are too many unique job titles to try to convert this to a dummy variable feature. Though dropping the "emp_title" would be a better option:**

# %%
df.drop('emp_title' , axis = 1, inplace = True)

# %% [markdown]
# #### 3. Checking & Evaluating the Employment Length worth in further analysis:

# %%
df['emp_length'].unique()
# Out:
# array(['10+ years', '4 years', '< 1 year', '6 years', '9 years',
#        '2 years', '3 years', '8 years', '7 years', '5 years', '1 year',
#        nan], dtype=object)

# %%
emp_length_ordering = ['< 1 year',
                       '1 year',
                       '2 years',
                       '3 years',
                       '4 years',
                       '5 years',
                       '6 years',
                       '7 years',
                       '8 years',
                       '9 years',
                       '10+ years']

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = df['emp_length'], order = emp_length_ordering, hue = df['emp_length'], palette = 'rocket')

plt.xlabel('Employee Length')
plt.ylabel('Count')
plt.title('Analyzing Employee Length')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Again Plotting the above countplot with a hue separating Fully Paid vs Charged Off:**

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = df['emp_length'], order = emp_length_ordering, hue = df['loan_status'], palette = 'rocket')

plt.xlabel('Employee Length')
plt.ylabel('Count')
plt.title('Analyzing Employee Length with Loan Status')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Calculating and visualizing the % of charge-offs per employment length:**

# %%
# Count total loans by employment length
count_emplength = df['emp_length'].value_counts()


# Filter charged off loans
charged_off_df = df[df['loan_status'] == 'Charged Off'] 

# Count charged off loans by employment length
count_emplength_charged = charged_off_df['emp_length'].value_counts()


# Calculate % of charge-offs per employment length
charged_percentile = (100 * count_emplength_charged / count_emplength)


# Create a DataFrame showing emp_length and their respective charged off percentages
# Note: dropna() is used to remove NaN from emp_length before creating the DataFrame (else there will be error)
charged_percent_df = pd.DataFrame({'emp_length' : df['emp_length'].dropna().unique() ,
                                   'charged_off_percent' : charged_percentile
                                  })

charged_percent_df
# Out:
#            emp_length  charged_off_percent
# emp_length
# 1 year      10+ years            19.913453
# 10+ years     4 years            18.418610
# 2 years      < 1 year            19.326206
# 3 years       6 years            19.523133
# 4 years       9 years            19.238477
# 5 years       2 years            19.218721
# 6 years       3 years            18.919438
# 7 years       8 years            19.477400
# 8 years       7 years            19.976002
# 9 years       5 years            20.047016
# < 1 year       1 year            20.687155

# %%
emp_length_ordering = ['< 1 year',
                       '1 year',
                       '2 years',
                       '3 years',
                       '4 years',
                       '5 years',
                       '6 years',
                       '7 years',
                       '8 years',
                       '9 years',
                       '10+ years']

plt.figure(figsize = (14,5))

sns.barplot(x= 'emp_length' , 
            y = 'charged_off_percent' , 
            data = charged_percent_df , 
            order =  emp_length_ordering, 
            palette = 'rocket'
           )

plt.xlabel('Employee Length')
plt.ylabel('Percentile of Charged Off')
plt.title('Analyzing the Charged Off Percentile')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qf/32t2k01x4jvc8n9npp_m0plm0000gn/T/ipykernel_7595/3000906641.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= 'emp_length' ,

# %% [markdown]
# **Here charge off rates are extremely similar across all employment lengths. Thus, dropping the emp_length column, would be better option:**

# %%
df.drop('emp_length' , axis = 1, inplace = True)

# %% [markdown]
# #### 4. Revisiting the DataFrame to see what feature columns still have missing data:

# %%
print('\n')
print('Analyzing Features having Missing Values:')
df.isnull().sum()
# Out:
# Analyzing Features having Missing Values:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %% [markdown]
# #### 5. Reviewing the title column vs the purpose column, as they seem to be repeated information:

# %%
df['purpose'].value_counts()
# Out:
# purpose
# debt_consolidation    234507
# credit_card            83019
# home_improvement       24030
# other                  21185
# major_purchase          8790
# small_business          5701
# car                     4697
# medical                 4196
# moving                  2854
# vacation                2452
# house                   2201
# wedding                 1812
# renewable_energy         329
# educational              257
# Name: count, dtype: int64

# %%
df['title'].value_counts()
# Out:
# title
# Debt consolidation            152472
# Credit card refinancing        51487
# Home improvement               15264
# Other                          12930
# Debt Consolidation             11608
#                                ...
# Graduation/Travel Expenses         1
# Daughter's Wedding Bill            1
# gotta move                         1
# creditcardrefi                     1
# Toxic Debt Payoff                  1
# Name: count, Length: 48816, dtype: int64

# %% [markdown]
# **The title column is simply a string subcategory/description of the purpose column. Thus, dropping the title column.**

# %%
df.drop('title' , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#   home_ownership  annual_inc verification_status   issue_d  ... pub_rec  \
# 0           RENT    117000.0        Not Verified  Jan-2015  ...     0.0
# 1       MORTGAGE     65000.0        Not Verified  Jan-2015  ...     0.0
# 2           RENT     43057.0     Source Verified  Jan-2015  ...     0.0
# 3           RENT     54000.0        Not Verified  Nov-2014  ...     0.0
# 4       MORTGAGE     55000.0            Verified  Apr-2013  ...     0.0
#
#   revol_bal  revol_util total_acc  initial_list_status  application_type  \
# ...

# %% [markdown]
# #### 6. Checking the mort_acc feature:

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %% [markdown]
# **Creating a value_counts of the mort_acc column:**

# %%
df['mort_acc'].value_counts()
# Out:
# mort_acc
# 0.0     139777
# 1.0      60416
# 2.0      49948
# 3.0      38049
# 4.0      27887
# 5.0      18194
# 6.0      11069
# 7.0       6052
# 8.0       3121
# 9.0       1656
# 10.0       865
# 11.0       479
# 12.0       264
# 13.0       146
# 14.0       107
# 15.0        61
# 16.0        37
# 17.0        22
# 18.0        18
# 19.0        15
# 20.0        13
# 24.0        10
# 22.0         7
# 21.0         4
# 25.0         4
# 27.0         3
# 32.0         2
# 31.0         2
# 23.0         2
# 26.0         2
# 28.0         1
# 30.0         1
# 34.0         1
# Name: count, dtype: int64

# %% [markdown]
# **Reviewing other columns to see which most highly correlates to mort_acc:**

# %%
print("Correlation with the mort_acc column")
mort_acc_correl = df.corr(numeric_only = True)['mort_acc']
mort_acc_correl

# mort_acc has correlation most with total_acc...
# Out:
# Correlation with the mort_acc column
# loan_amnt               0.222315
# int_rate               -0.082583
# installment             0.193694
# annual_inc              0.236320
# dti                    -0.025439
# open_acc                0.109205
# pub_rec                 0.011552
# revol_bal               0.194925
# revol_util              0.007514
# total_acc               0.381072
# mort_acc                1.000000
# pub_rec_bankruptcies    0.027239
# loan_repaid             0.073111
# Name: mort_acc, dtype: float64

# %% [markdown]
# **Here, total_acc feature correlates with the mort_acc. Hence, filling up the missing values in the mort_acc column with the mean mort_acc for each total_acc group:**

# %%
# Compute the group-wise mean of mort_acc based on total_acc
fill_mean_val = df.groupby('total_acc')['mort_acc'].transform('mean')

# Fill missing mort_acc values with the corresponding group mean
df['mort_acc'] = df['mort_acc'].fillna(fill_mean_val)

# %% [markdown]
# #### 7. revol_util and the pub_rec_bankruptcies have missing data points, but they account for less than 0.5% of the total data.Thus Dropping rows where either 'revol_util' or 'pub_rec_bankruptcies' is missing:

# %%
df.dropna(subset=['revol_util', 'pub_rec_bankruptcies'], inplace=True)

# Check remaining missing values in the DataFrame
df.isnull().sum()

# ALL MISSING DATA TREATED...
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# installment             0
# grade                   0
# sub_grade               0
# home_ownership          0
# annual_inc              0
# verification_status     0
# issue_d                 0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# address                 0
# loan_repaid             0
# dtype: int64

# %% [markdown]
# ----
# ----
# # 🏷️ Data PreProcessing - Categorical Variables and Dummy Variables:
#
#
# ### Listing all the columns that are currently non-numeric:

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'earliest_cr_line',
#        'initial_list_status', 'application_type', 'address'],
#       dtype='object')

# %% [markdown]
# ### TERM:
#
# **Converting the term feature into either a 36 or 60 integer numeric data type using .apply() or .map().**

# %%
df['term'].value_counts()
# Out:
# term
# 36 months    301247
# 60 months     93972
# Name: count, dtype: int64

# %%
df['term'] = df['term'].apply(lambda term : int(term[:3]))

# %% [markdown]
# ### GRADE:
#
# **As grade is part of sub_grade, so dropping the grade feature.**

# %%
df.drop('grade', axis = 1 , inplace = True)

# or use 
# df = df['grade', axis = 1], if not want to use ---> inplace

# %% [markdown]
# **Converting the subgrade into dummy variables. Then concatenate these new columns to the original dataframe, then dropping the original categorical column:**
#
# #### 📌  `drop_first = True`:
# 1. Using `drop_first=True` in `pd.get_dummies()` to avoid multicollinearity (dummy variable trap) in linear models.
# 2. This is important for models like **Linear Regression** and **Logistic Regression**.
# 3. It is **not required** for tree-based models such as **Random Forest** or **XGBoost**.

# %%
dummies_subgrade = pd.get_dummies(df['sub_grade'], drop_first = True).astype(int)
df = pd.concat([df , dummies_subgrade], axis = 1)
df.drop('sub_grade', axis = 1 , inplace = True)

# %% [markdown]
# ### VERIFICATION STATUS , APPLICATION TYPE , INITIAL LIST STATUS , PURPOSE:
# **Converting these columns: ['verification_status', 'application_type','initial_list_status','purpose'] into dummy variables and concatenate them with the original dataframe, then Dropping original categorical columns:**

# %%
# Create dummy variables (one-hot encoded) for 'verification_status', drop first to avoid multicollinearity
dummies_verf_stat = pd.get_dummies(df['verification_status'], drop_first=True).astype(int)

# Create dummy variables for 'application_type', drop first category
dummies_appl_type = pd.get_dummies(df['application_type'], drop_first=True).astype(int)

# Create dummy variables for 'initial_list_status', drop first
dummies_init_lstat = pd.get_dummies(df['initial_list_status'], drop_first=True).astype(int)

# Create dummy variables for 'purpose', drop first to avoid dummy variable trap
dummies_purpose = pd.get_dummies(df['purpose'], drop_first=True).astype(int)

# Concatenate all dummy DataFrames with the main DataFrame along columns (axis=1)
df = pd.concat([df, dummies_verf_stat, dummies_appl_type, dummies_init_lstat, dummies_purpose], axis=1)

# Drop original categorical columns after encoding
df.drop(['verification_status', 'application_type', 'initial_list_status', 'purpose'], axis=1, inplace=True)

# %% [markdown]
# ### HOME OWNERSHIP:
# **Reviewing the value_counts for the home_ownership column:**

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    198022
# RENT        159395
# OWN          37660
# OTHER          110
# NONE            29
# ANY              3
# Name: count, dtype: int64

# %% [markdown]
# **Converting these to dummy variables. Before which replacing the NONE and ANY with OTHER, though, ending up with just 4 categories, MORTGAGE, RENT, OWN, OTHER. Then concatenating them with the original dataframe, and lastly dropping the original column:**

# %%
df['home_ownership'] = df['home_ownership'].replace(['NONE' , 'ANY'] , 'OTHER')

dummies_home_onship = pd.get_dummies(df['home_ownership'] , drop_first = True).astype(int)

df = pd.concat([df , dummies_home_onship], axis = 1)

df.drop('home_ownership' , axis = 1 , inplace = True)

# %% [markdown]
# ### ADDRESS:
# **Extracting the zip code from the address in the data set, and creating a zip_code column:**

# %%
df['zip_code'] = df['address'].apply(lambda ad : int(ad[-5:]))

# %% [markdown]
# **Making the zip_code column into dummy variables using pandas. Then, Concatenating the result and dropping the original zip_code column along with dropping the address column:**

# %%
dummies_zipcode = pd.get_dummies(df['zip_code'], drop_first = True).astype(int)
df = pd.concat([df , dummies_zipcode] , axis = 1)

# %%
df.drop(['address', 'zip_code'] , axis = 1 , inplace = True)

# %% [markdown]
# ### ISSUE DATE:
#
# **Dropping this feature:**

# %%
df.drop('issue_d', axis = 1 , inplace = True)

# %% [markdown]
# ### EARLIEST_CR_LINE:
# **Extracting the year from earliest_cr_line using .apply, store it as a numeric column earliest_cr_year, and drop the original earliest_cr_line column:**

# %%
df['earliest_cr_year'] = df['earliest_cr_line'].apply(lambda line : int(line[-4 :]))

# %%
df.drop('earliest_cr_line' , axis = 1 , inplace = True )

# %% [markdown]
# ### LOAN STATUS:
# **Dropping the load_status column we created earlier, since its a duplicate of the loan_repaid column. We'll use the loan_repaid column since its already in 0s and 1s:**

# %%
df.drop('loan_status', axis = 1 , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 395219 entries, 0 to 396029
# Data columns (total 79 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             395219 non-null  float64
#  1   term                  395219 non-null  int64
#  2   int_rate              395219 non-null  float64
#  3   installment           395219 non-null  float64
#  4   annual_inc            395219 non-null  float64
#  5   dti                   395219 non-null  float64
#  6   open_acc              395219 non-null  float64
#  7   pub_rec               395219 non-null  float64
#  8   revol_bal             395219 non-null  float64
#  9   revol_util            395219 non-null  float64
#  10  total_acc             395219 non-null  float64
#  11  mort_acc              395219 non-null  float64
#  12  pub_rec_bankruptcies  395219 non-null  float64
#  13  loan_repaid           395219 non-null  int64
# ...

# %% [markdown]
# ----
# ----
#
# # ✂️ Train Test Split:

# %%
from sklearn.model_selection import train_test_split

# %%
# Separate the features (independent variables) from the target variable
x = df.drop('loan_repaid', axis=1)  # All columns except 'loan_repaid' (features)
y = df['loan_repaid']               # Target variable to predict (label)


# Convert all column names to strings (as few column has name such as 5113 , 11650 etc, thus converting these int to str)
x.columns = x.columns.astype(str)

# %%
x_train , x_test , y_train , y_test = train_test_split( x , y , test_size = 0.2 , random_state = 101)

# %% [markdown]
# ## 📊 Normalizing the Data:

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ----
# ----
# # 🧠 Creating the Model:

# %%
import tensorflow as tf

# Use tf.keras consistently
Sequential = tf.keras.models.Sequential
Dense = tf.keras.layers.Dense
Activation = tf.keras.layers.Activation
Dropout = tf.keras.layers.Dropout
EarlyStopping = tf.keras.callbacks.EarlyStopping

# %%
model = Sequential()

model.add(Dense(80, activation = 'relu'))
model.add(Dropout(0.4))


model.add(Dense(64 , activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(32 , activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(16 , activation = 'relu'))
model.add(Dropout(0.4))


model.add(Dense(1 , activation = 'sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
# Declaring EarlyStopping to prevent overfitting
early_stop = EarlyStopping(
    monitor='val_loss',          #  Watch the validation loss during training
    patience=25,                 #  If no improvement for 25 epochs, stop training
    restore_best_weights=True    #  Revert to the model state with the best val_loss
)

# %%
model.fit(x = x_train ,
          y = y_train ,
          epochs = 400 ,
          batch_size = 64 ,
          validation_data = (x_test, y_test) ,
          callbacks = [early_stop]
          )
# Out:
# Epoch 1/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 4s 581us/step - loss: 0.3429 - val_loss: 0.2653
# Epoch 2/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 2s 475us/step - loss: 0.2688 - val_loss: 0.2647
# Epoch 3/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 2s 485us/step - loss: 0.2660 - val_loss: 0.2636
# Epoch 4/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 2s 463us/step - loss: 0.2653 - val_loss: 0.2629
# Epoch 5/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 2s 465us/step - loss: 0.2647 - val_loss: 0.2649
# Epoch 6/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 2s 447us/step - loss: 0.2641 - val_loss: 0.2633
# Epoch 7/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 2s 449us/step - loss: 0.2653 - val_loss: 0.2640
# Epoch 8/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 2s 451us/step - loss: 0.2640 - val_loss: 0.2628
# Epoch 9/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 2s 467us/step - loss: 0.2642 - val_loss: 0.2641
# Epoch 10/400
# 4941/4941 ━━━━━━━━━━━━━━━━━━━━ 2s 460us/step - loss: 0.2636 - val_loss: 0.2631
# Epoch 11/400
# ...

# %% [markdown]
# ----
# ----
#
# # 🎯 Evaluating Model Performance:
#
# **Plotting out the validation loss and the training loss:**

# %%
# Convert training history dictionary to a DataFrame
losses_df = pd.DataFrame(model.history.history)  

# Plot all recorded metrics (loss, val_loss, etc.)
losses_df.plot()  

# Label the x-axis as 'epochs'
plt.xlabel('epochs')  

# Label the y-axis as 'loss' (applies to loss and val_loss curves)
plt.ylabel('loss')  

# Automatically adjust layout to prevent overlap/clipping
plt.tight_layout()  

# Display the final plot
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Get probabilities
predictions = model.predict(x_test)

# Convert probabilities to class labels (0 or 1)
predictions = (predictions > 0.5).astype(int)
# Out:
# 2471/2471 ━━━━━━━━━━━━━━━━━━━━ 1s 218us/step

# %%
print('CLASSIFICATION REPORT:')
print(classification_report(y_test,predictions))

print('\n')

print('CONFUSION MATRIX:')
print(confusion_matrix(y_test,predictions))
# Out:
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60     15658
#            1       0.88      1.00      0.93     63386
#
#     accuracy                           0.89     79044
#    macro avg       0.94      0.71      0.77     79044
# weighted avg       0.90      0.89      0.87     79044
#
#
#
# CONFUSION MATRIX:
# [[ 6720  8938]
#  [    0 63386]]

# %% [markdown]
# ----
# ----
#
# # 🧬 Making a Prediction for a Random Existing User:

# %%
import random
random.seed(101)
random_ind = random.randint(0,len(df))

new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]
new_customer
# Out:
# loan_amnt           25000.00
# term                   60.00
# int_rate               18.24
# installment           638.11
# annual_inc          61665.00
#                       ...
# 48052                   0.00
# 70466                   0.00
# 86630                   0.00
# 93700                   0.00
# earliest_cr_year     1996.00
# Name: 305323, Length: 78, dtype: float64

# %%
prediction = model.predict(new_customer.values.reshape(1, 78))
predicted_class = (prediction > 0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ### Prediction:

# %%
if df.iloc[random_ind]['loan_repaid'] == 1.0:
    print('Yes, person ended up paying the loan.')

else:
    print('No, person did not paid the loan.')
# Out:
# Yes, person ended up paying the loan.

# %% [markdown]
# ----
# # END
